# %%
class Directory():
    def __init__(self, name: str, parent: "Directory | None" = None) -> None:
        self.name = name
        self.files = {}
        self.subdirectories: dict[str, Directory] = {}
        self.parent = parent
    
    def add_file(self, file_name: str, file_size: int) -> None:
        if file_name not in self.files:
            self.files[file_name] = file_size
    
    def add_dir(self, dir_name: str) -> None:
        if dir_name not in self.subdirectories:
            self.subdirectories[dir_name] = Directory(dir_name, self)
    
    def get_subdir(self, dir_name: str) -> "Directory":
        return self.subdirectories[dir_name]
    
    def size(self):
        total_size = sum(file_size for file_size in self.files.values())
        total_size += sum(subdir.size() for subdir in self.subdirectories.values())
        return total_size

    def total_filtered(self, filter_size: int = 100000):
        own_size = self.size()
        total_size = own_size if own_size <= filter_size else 0
        total_size += sum(subdir.total_filtered() for subdir in self.subdirectories.values())
        return total_size
    
    def min_dir_over_threshold(self, filter_threshhold: int) -> "Directory | None":
        subdir_best = []
        for subdir in self.subdirectories.values():
            subdir_total_filtered = subdir.min_dir_over_threshold(filter_threshhold)
            if subdir_total_filtered is not None:
                subdir_best.append(subdir_total_filtered)

        if subdir_best:
            return min(
                subdir_best,
                key=lambda p: p.size()
            )
        else:
            if self.size() >= filter_threshhold:
                return self
            else:
                return None
    
    def str_rep(self, level: int = 0) -> str:
        ret_str = " " * level * 2
        ret_str += f"- {self.name} (dir, dirsize={self.size()})\n"
        for file_name, file_size in self.files.items():
            ret_str += " " * (level + 1) * 2
            ret_str += f"- {file_name} (file, size={file_size}\n"
        for subdir in self.subdirectories.values():
            ret_str += subdir.str_rep(level + 1)
        return ret_str

# %%
def parse_input(filename: str):
    root_dir = Directory("/")
    curr_dir = root_dir
    with open(filename) as f:
        for row in f:
            row = row.rstrip().split(" ")
            if row[0] == "$":    
                if row[1] == "cd":
                    if row[2] == "/":
                        curr_dir = root_dir
                    elif row[2] == "..":
                        curr_dir = curr_dir.parent
                    else:
                        curr_dir = curr_dir.get_subdir(row[2])
                elif row[1] == "ls":
                    continue
            elif row[0] == "dir":
                curr_dir.add_dir(row[1])
            else:
                curr_dir.add_file(row[1], int(row[0]))
    return root_dir

# %%
test_input = parse_input("test-input.txt")
print(test_input.str_rep())
print(test_input.total_filtered())
# Out:
# - / (dir, dirsize=48381165)
#   - b.txt (file, size=14848514
#   - c.dat (file, size=8504156
#   - a (dir, dirsize=94853)
#     - f (file, size=29116
#     - g (file, size=2557
#     - h.lst (file, size=62596
#     - e (dir, dirsize=584)
#       - i (file, size=584
#   - d (dir, dirsize=24933642)
#     - j (file, size=4060174
#     - d.log (file, size=8033020
#     - d.ext (file, size=5626152
#     - k (file, size=7214296
#
# 95437

# %%
test_input = parse_input("input.txt")
print(test_input.str_rep())
print(test_input.total_filtered())
# Out:
# - / (dir, dirsize=42476859)
#   - pnm.slh (file, size=307337
#   - zcrfndg.cms (file, size=212421
#   - bsnqsfm (dir, dirsize=179236)
#     - lccnhn (file, size=179236
#   - dtqvbspj (dir, dirsize=494450)
#     - gdjfp.mfp (file, size=221336
#     - jjgpvcqv.jlq (file, size=273114
#   - hhhtrws (dir, dirsize=10632043)
#     - mgvdbtl.ztt (file, size=1606
#     - wprqtd.wph (file, size=27538
#     - gcbg (dir, dirsize=3658797)
#       - lccnhn (file, size=186683
#       - zjfs.mdf (file, size=32944
#       - bgcwh (dir, dirsize=211273)
#         - nvns (file, size=211273
#       - bsnqsfm (dir, dirsize=1069939)
#         - dtqvbspj (file, size=210022
#         - pnm.slh (file, size=189603
#         - rcsffv.gbt (file, size=199755
#         - bsnqsfm (dir, dirsize=292856)
#           - bsnqsfm.vww (file, size=292856
#         - gpcpgfh (dir, dirsize=177703)
#           - jrr.jnj (file, size=177703
#       - jjgpvcqv (dir, dirsize=2003950)
#         - bsnqsfm.fnn (file, size=233963
#         - gpcpgfh.gtw (file, size=127603
#         - jrs.bdw (file, size=48213
#         - pnm.slh (file, size=172974
#         - jjgpvcqv (dir, dirsize=1421197)
#           - qpmnqwvl (file, size=254570
#           - rrvjrv.zbp (file, size=258040
#           - bqnctqvn (dir, dirsize=418596)
#             - bsnqsfm.pql (file, size=106211
#             - dtqvbspj (file, size=299973
#             - nzrst (dir, dirsize=12412)
#               - whtfvrl (dir, dirsize=12412)
#                 - vzdrqs.rwt (file, size=12412
#           - bsnqsfm (dir, dirsize=293832)
#             - bggllqhj.dvb (file, size=293832
#           - gpcpgfh (dir, dirsize=196159)
#             - jrr.jnj (file, size=196159
#       - rqbnd (dir, dirsize=154008)
#         - ddjrjp (file, size=97630
#         - rsb (file, size=56378
#     - jjgpvcqv (dir, dirsize=6259122)
#       - bsnqsfm.mgf (file, size=89238
#       - pnm.slh (file, size=164176
#       - dvsst (dir, dirsize=805852)
#         - dtqvbspj (file, size=286924
#         - hcnqdmg.zst (file, size=252366
#         - wgfdmgmh.ptw (file, size=266562
#       - gpcpgfh (dir, dirsize=2165662)
#         - jrs.bdw (file, size=91199
#         - rspd.vmj (file, size=78761
#         - tbrbw (dir, dirsize=1406757)
#           - bjd.csj (file, size=195696
#           - lccnhn (file, size=56063
#           - pnm.slh (file, size=193863
#           - qpd.dtq (file, size=121918
#           - rcsffv.gbt (file, size=209757
#           - rmqlpvq (dir, dirsize=629460)
#             - lhdqqbg.fgm (file, size=255533
#             - qltvgnrp.gfd (file, size=68413
#             - gjgfvt (dir, dirsize=242867)
#               - zqbdmpb (file, size=242867
#             - wqfcnlzq (dir, dirsize=62647)
#               - vhhscrvb (dir, dirsize=62647)
#                 - rcsffv.gbt (file, size=62647
#         - vvm (dir, dirsize=296046)
#           - dscllv.qwl (file, size=281698
#           - rmgpnprq (file, size=14348
#         - wplf (dir, dirsize=292899)
#           - jjgpvcqv (file, size=44465
#           - vpsfbjh.zsj (file, size=248434
#       - jjgpvcqv (dir, dirsize=2134045)
#         - dhfcbc (dir, dirsize=421258)
#           - lccnhn (file, size=224134
#           - tns (file, size=197124
#         - jjgpvcqv (dir, dirsize=406609)
#           - jrr.jnj (file, size=126322
#           - jrs.bdw (file, size=280287
#         - ltclg (dir, dirsize=1066921)
#           - jrr.jnj (file, size=47501
#           - mgvdbtl.gll (file, size=24374
#           - pnm.slh (file, size=227751
#           - wvsfr (file, size=286088
#           - fdfn (dir, dirsize=32987)
#             - hmt (file, size=32987
#           - mgvdbtl (dir, dirsize=448220)
#             - pnm.slh (file, size=201629
#             - whtcjvh (file, size=246591
#         - ptbsgmlr (dir, dirsize=239257)
#           - rcsffv.gbt (file, size=239257
#       - mhrzj (dir, dirsize=493324)
#         - mgvdbtl.rzf (file, size=279222
#         - rvjnddbr (file, size=214102
#       - tmh (dir, dirsize=152958)
#         - rcsffv.gbt (file, size=152958
#       - vmwz (dir, dirsize=253867)
#         - bsnqsfm.djc (file, size=131525
#         - jrs.bdw (file, size=122342
#     - mgvdbtl (dir, dirsize=24916)
#       - tcsltrml (file, size=24916
#     - qhv (dir, dirsize=660064)
#       - jwdg.wbg (file, size=153239
#       - hncvrlbw (dir, dirsize=506825)
#         - clmwn.ztj (file, size=178499
#         - jrr.jnj (file, size=297967
#         - sntbnf.whh (file, size=30359
#   - ldmsq (dir, dirsize=8687846)
#     - jngnzc (dir, dirsize=1069913)
#       - dzlcq (dir, dirsize=70984)
#         - lccnhn (file, size=70984
#       - gpcpgfh (dir, dirsize=288159)
#         - hztmtp.fpj (file, size=288159
#       - rlwwwngc (dir, dirsize=641181)
#         - bsnqsfm.rtr (file, size=173335
#         - jrr.jnj (file, size=292723
#         - lccnhn (file, size=175123
#       - swrlvd (dir, dirsize=69589)
#         - fwrt (file, size=69589
#     - psgrjgr (dir, dirsize=1142486)
#       - dtqvbspj.hjw (file, size=283186
#       - jrs.bdw (file, size=104691
#       - lccnhn (file, size=286657
#       - rcsffv.gbt (file, size=258194
#       - fcvqsp (dir, dirsize=209758)
#         - fzqmqlvs.hsc (file, size=209758
#     - rgwp (dir, dirsize=11060)
#       - nwg.qcg (file, size=11060
#     - rtsmnzm (dir, dirsize=2842225)
#       - rdv (dir, dirsize=291554)
#         - nngdwngf.jpm (file, size=189234
#         - qbq (file, size=102320
#       - sdwmbsz (dir, dirsize=2083367)
#         - jjgpvcqv.cvz (file, size=140827
#         - dfzw (dir, dirsize=168631)
#           - dhbfr (file, size=168631
#         - jbnsvcv (dir, dirsize=659560)
#           - lsgnjrn (file, size=20840
#           - lvtbqlh (file, size=83537
#           - bsnqsfm (dir, dirsize=74345)
#             - jrr.jnj (file, size=74345
#           - qfmj (dir, dirsize=480838)
#             - bfvwng (dir, dirsize=207083)
#               - qzdpp (dir, dirsize=207083)
#                 - jjgpvcqv (dir, dirsize=207083)
#                   - rchw.lgb (file, size=207083
#             - jjgpvcqv (dir, dirsize=273755)
#               - dqmb (file, size=273755
#         - jjgpvcqv (dir, dirsize=1114349)
#           - dtqvbspj.rww (file, size=190922
#           - lccnhn (file, size=59784
#           - mwvpgtzm (file, size=293765
#           - vtbln (dir, dirsize=395727)
#             - jrs.bdw (file, size=19558
#             - lccnhn (file, size=72791
#             - pnm.slh (file, size=262803
#             - sbdz (file, size=40575
#           - wph (dir, dirsize=174151)
#             - jrr.jnj (file, size=174151
#       - tjwht (dir, dirsize=467304)
#         - rcsffv.gbt (file, size=136586
#         - mgvdbtl (dir, dirsize=330718)
#           - gtmbf (dir, dirsize=330718)
#             - jvs.gvw (file, size=61244
#             - rcsffv.gbt (file, size=269474
#     - wsd (dir, dirsize=3622162)
#       - dtqvbspj.mjl (file, size=275247
#       - jrr.jnj (file, size=88516
#       - lccnhn (file, size=77096
#       - tqzmlsz (file, size=120975
#       - zvzhjd.ggw (file, size=215518
#       - gpcpgfh (dir, dirsize=460025)
#         - lccnhn (file, size=217225
#         - qtnqzql (dir, dirsize=242800)
#           - rzfvcjvh (file, size=242800
#       - jdnfsqzd (dir, dirsize=604210)
#         - ppdh (file, size=293894
#         - rcsffv.gbt (file, size=310316
#       - lspqh (dir, dirsize=367991)
#         - pspghgw (dir, dirsize=367991)
#           - gpcpgfh.zht (file, size=105894
#           - nccmrdjv.tml (file, size=20657
#           - nrb.zrj (file, size=241440
#       - pfcmb (dir, dirsize=1412584)
#         - cfnptz (file, size=64751
#         - nfcdscgz (file, size=288252
#         - pnm.slh (file, size=309178
#         - dmlsqf (dir, dirsize=553324)
#           - czhbvv.fvc (file, size=82960
#           - dtqvbspj.mqp (file, size=238189
#           - lccnhn (file, size=232175
#         - dtqvbspj (dir, dirsize=197079)
#           - jrs.bdw (file, size=99045
#           - fpq (dir, dirsize=98034)
#             - bnbvjg.nfq (file, size=98034
#   - pqcndb (dir, dirsize=17831881)
#     - rcsffv.gbt (file, size=302354
#     - dtqvbspj (dir, dirsize=134541)
#       - mgvdbtl.gbr (file, size=134541
#     - fvrtmdg (dir, dirsize=600719)
#       - gpcpgfh.cgh (file, size=231704
#       - jrr.jnj (file, size=304822
#       - gpcpgfh (dir, dirsize=64193)
#         - ztqztct.ctr (file, size=64193
#     - gpcpgfh (dir, dirsize=5416300)
#       - hqcjs.fsf (file, size=129101
#       - tzgn.sqv (file, size=149226
#       - zbjzcn (file, size=257657
#       - cmg (dir, dirsize=1331103)
#         - bbrbwdw.mtf (file, size=54041
#         - dtqvbspj.hjj (file, size=233793
#         - jjgpvcqv.sls (file, size=227618
#         - rcsffv.gbt (file, size=36553
#         - vsjs (dir, dirsize=779098)
#           - bsnqsfm (file, size=199262
#           - jrs.bdw (file, size=73538
#           - mtfzjhc (file, size=20726
#           - dqpqvsfn (dir, dirsize=91215)
#             - ppfmvz (file, size=91215
#           - ghw (dir, dirsize=394357)
#             - jrr.jnj (file, size=307330
#             - pnm.slh (file, size=25726
#             - bwhn (dir, dirsize=61301)
#               - gpcpgfh (dir, dirsize=61301)
#                 - mhchvsnp.lpv (file, size=61301
#       - jjgpvcqv (dir, dirsize=281936)
#         - zjfrwg (file, size=281936
#       - lmb (dir, dirsize=60362)
#         - mmqr (dir, dirsize=60362)
#           - mbjdfmf.wfh (file, size=60362
#       - lzgc (dir, dirsize=211543)
#         - rcsffv.gbt (file, size=211543
#       - nqvzvfb (dir, dirsize=513390)
#         - lccnhn (file, size=288538
#         - rcsffv.gbt (file, size=224852
#       - rbh (dir, dirsize=2481982)
#         - mgvdbtl.rdd (file, size=75165
#         - cwgc (dir, dirsize=254910)
#           - ghsbvcw.wgh (file, size=254910
#         - gpcpgfh (dir, dirsize=419940)
#           - lccnhn (file, size=8668
#           - mcpd (file, size=145750
#           - rcsffv.gbt (file, size=265522
#         - hdmmgms (dir, dirsize=1266376)
#           - jrs.bdw (file, size=203642
#           - rcsffv.gbt (file, size=19047
#           - tbdf (file, size=215131
#           - dtqvbspj (dir, dirsize=61268)
#             - hjztnq (file, size=46484
#             - tmmf.ggs (file, size=14784
#           - gpcpgfh (dir, dirsize=306663)
#             - jrs.bdw (file, size=123990
#             - mgvdbtl (file, size=52381
#             - rrqp.pmz (file, size=130292
#           - tgqbtw (dir, dirsize=460625)
#             - bsnqsfm (dir, dirsize=279305)
#               - mgvdbtl.mhc (file, size=279305
#             - nnn (dir, dirsize=181320)
#               - jjgpvcqv.zcn (file, size=181320
#         - jwqdv (dir, dirsize=306471)
#           - jjgpvcqv.jbv (file, size=306471
#         - mzt (dir, dirsize=159120)
#           - wcfjbfsb.vlq (file, size=159120
#     - jjgpvcqv (dir, dirsize=4424554)
#       - jjnbtgh (file, size=235210
#       - lccnhn (file, size=116214
#       - drmmqldt (dir, dirsize=690999)
#         - bsnqsfm (dir, dirsize=200217)
#           - gpcpgfh.bmf (file, size=200217
#         - gpcpgfh (dir, dirsize=302915)
#           - jjgpvcqv.cgs (file, size=183548
#           - rcsffv.gbt (file, size=119367
#         - jjgpvcqv (dir, dirsize=187867)
#           - bzhsjfq (dir, dirsize=37713)
#             - pnm.slh (file, size=37713
#           - lptnp (dir, dirsize=150154)
#             - jjgpvcqv.jpt (file, size=150154
#       - jjgpvcqv (dir, dirsize=149237)
#         - csvpf (dir, dirsize=149237)
#           - bdsqr.ptg (file, size=96915
#           - gpcpgfh.hbw (file, size=15712
#           - pnm.slh (file, size=13419
#           - vhzngpw.bdp (file, size=23191
#       - mzj (dir, dirsize=216100)
#         - fblqpwgd.rmb (file, size=216100
#       - qcclcdd (dir, dirsize=550287)
#         - bdz.flj (file, size=67202
#         - dtqvbspj (file, size=51451
#         - rhc.qtg (file, size=36642
#         - slqzl.hgz (file, size=252808
#         - mgvdbtl (dir, dirsize=142184)
#           - dtqvbspj (dir, dirsize=142184)
#             - pnm.slh (file, size=142184
#       - rtnnjct (dir, dirsize=2247380)
#         - bsnqsfm (dir, dirsize=157447)
#           - gbp (dir, dirsize=157447)
#             - gpcpgfh (dir, dirsize=157447)
#               - msdhpv (file, size=157447
#         - dtqvbspj (dir, dirsize=882344)
#           - fbpz (dir, dirsize=118001)
#             - zzffss.qdv (file, size=118001
#           - mgvdbtl (dir, dirsize=764343)
#             - gtbpnhhm (dir, dirsize=422909)
#               - mgvdbtl.zhd (file, size=115199
#               - pbqqz.dvg (file, size=307710
#             - rvjdhdvf (dir, dirsize=341434)
#               - lccnhn (file, size=192704
#               - qsv.nzw (file, size=49374
#               - vnlq (dir, dirsize=99356)
#                 - zwtwvdb (dir, dirsize=99356)
#                   - cqfppfg.cwl (file, size=99356
#         - ftlr (dir, dirsize=439951)
#           - fdm (dir, dirsize=439951)
#             - pdzbthz (dir, dirsize=439951)
#               - gmvg (file, size=286299
#               - jrr.jnj (file, size=32579
#               - gmpzrfv (dir, dirsize=121073)
#                 - tfwc.sjb (file, size=44930
#                 - wtwpz (file, size=76143
#         - grpln (dir, dirsize=351247)
#           - thsbgczd (dir, dirsize=231385)
#             - lccnhn (file, size=231385
#           - vdmt (dir, dirsize=119862)
#             - qzwzwlpr (dir, dirsize=119862)
#               - qbpglhp.pmz (file, size=119862
#         - wtjfbzjq (dir, dirsize=416391)
#           - cvjrn.mmz (file, size=308656
#           - mgvdbtl.pjv (file, size=107735
#       - trgbfqb (dir, dirsize=219127)
#         - jrr.jnj (file, size=59890
#         - mhhbp (dir, dirsize=159237)
#           - bsnqsfm (dir, dirsize=80555)
#             - trsl.zjm (file, size=80555
#           - hvjtmr (dir, dirsize=78682)
#             - cgjqlrw (file, size=78682
#     - mgvdbtl (dir, dirsize=1399019)
#       - bsnqsfm.jft (file, size=85693
#       - gvfz (file, size=136814
#       - jjgpvcqv.phc (file, size=243282
#       - mrq (file, size=23472
#       - ztrvjzw.gjj (file, size=188849
#       - gpcpgfh (dir, dirsize=695093)
#         - blt (file, size=172798
#         - bfjb (dir, dirsize=9385)
#           - fhgqhrnq (file, size=9385
#         - dtqvbspj (dir, dirsize=115949)
#           - zrtpvzh (dir, dirsize=115949)
#             - gjcpswqv.tqg (file, size=115949
#         - lwtj (dir, dirsize=396961)
#           - dtqvbspj.tmv (file, size=269246
#           - jrr.jnj (file, size=106980
#           - ldjswqtb.plp (file, size=20735
#       - tdnhp (dir, dirsize=25816)
#         - lccnhn (file, size=25816
#     - pftswtnl (dir, dirsize=5349656)
#       - blg.vhz (file, size=60146
#       - mgvdbtl.cvq (file, size=165072
#       - wtvlsbbf (file, size=101085
#       - zfhlb.fmg (file, size=139565
#       - cjzl (dir, dirsize=51636)
#         - hmwmvgg (file, size=51636
#       - mgvdbtl (dir, dirsize=490254)
#         - pjjfwhwj (file, size=118691
#         - rcsffv.gbt (file, size=74684
#         - rgmn.csn (file, size=253814
#         - dtlr (dir, dirsize=43065)
#           - dtqvbspj (file, size=43065
#       - rdhdqvm (dir, dirsize=108607)
#         - bsnqsfm.rjd (file, size=103093
#         - lccnhn (file, size=5514
#       - swgdh (dir, dirsize=2615714)
#         - jjgpvcqv (file, size=230643
#         - ltnlhbln.bqp (file, size=296232
#         - rcsffv.gbt (file, size=199830
#         - dwznjd (dir, dirsize=379176)
#           - jrs.bdw (file, size=138849
#           - mgvdbtl (file, size=240327
#         - mgvdbtl (dir, dirsize=880115)
#           - dgrzgpr (file, size=293382
#           - jjgpvcqv.lwt (file, size=218657
#           - rcsffv.gbt (file, size=125455
#           - pbw (dir, dirsize=242621)
#             - tnt.zbl (file, size=242621
#         - nbpdfrv (dir, dirsize=629718)
#           - nfqbq.zfg (file, size=297826
#           - qvr (file, size=183227
#           - rcsffv.gbt (file, size=148665
#       - tgwws (dir, dirsize=1617577)
#         - bhr (dir, dirsize=1310649)
#           - wfjfvb (dir, dirsize=1310649)
#             - lwnz (file, size=13720
#             - wrgb.ntr (file, size=38140
#             - jgfbpwjh (dir, dirsize=1258789)
#               - cbtdqb (file, size=207048
#               - mgvdbtl (file, size=176591
#               - nwflw.mmp (file, size=311612
#               - pwrrz (file, size=92978
#               - rnzzs.wrr (file, size=273467
#               - vsmgcv (dir, dirsize=197093)
#                 - dpdmspz (dir, dirsize=197093)
#                   - bsnqsfm (dir, dirsize=197093)
#                     - wzqlhhpv.lgb (file, size=197093
#         - gpcpgfh (dir, dirsize=306928)
#           - lccnhn (file, size=98093
#           - llplrrr.jrp (file, size=208835
#     - zwph (dir, dirsize=204738)
#       - cmznd (dir, dirsize=204738)
#         - zhhm (dir, dirsize=204738)
#           - rjh.qjf (file, size=204738
#   - pwtqzwv (dir, dirsize=4131645)
#     - gbcccm.jdc (file, size=21382
#     - mgvdbtl.vrm (file, size=262556
#     - hthq (dir, dirsize=2002618)
#       - dtqvbspj (dir, dirsize=417341)
#         - gpcpgfh.wpc (file, size=35525
#         - jjgpvcqv (file, size=4808
#         - lrvftwzb (dir, dirsize=125914)
#           - rcsffv.gbt (file, size=92705
#           - wvthcng.qlf (file, size=33209
#         - nzvbpcwd (dir, dirsize=251094)
#           - tzvclhw (dir, dirsize=251094)
#             - gpcpgfh.bpj (file, size=251094
#       - mgvdbtl (dir, dirsize=817653)
#         - hvzhcpr.dbc (file, size=229319
#         - lrvlp.bnl (file, size=301679
#         - pjq (file, size=157154
#         - sgqsjl (file, size=129501
#       - wgcss (dir, dirsize=767624)
#         - fpmmqmv (file, size=37019
#         - gpcpgfh.mrm (file, size=286113
#         - lccnhn (file, size=132664
#         - pnm.slh (file, size=194995
#         - jjgpvcqv (dir, dirsize=116833)
#           - pnm.slh (file, size=116833
#     - jcsmcf (dir, dirsize=146144)
#       - jjgpvcqv.jvj (file, size=146144
#     - jjgpvcqv (dir, dirsize=977695)
#       - gdrqbn (dir, dirsize=151579)
#         - bsnqsfm.zjh (file, size=149865
#         - jjgpvcqv.lwq (file, size=1714
#       - nwbqdd (dir, dirsize=826116)
#         - bsnqsfm (file, size=14359
#         - dpqt.lph (file, size=77969
#         - dtqvbspj.svq (file, size=285861
#         - hhsfwctl.hng (file, size=156597
#         - mgvdbtl (file, size=15497
#         - gpcpgfh (dir, dirsize=275833)
#           - gpcpgfh.hdd (file, size=275833
#     - twrjfd (dir, dirsize=503531)
#       - gpcpgfh.zcb (file, size=302115
#       - rcsffv.gbt (file, size=20848
#       - gqlqnpvm (dir, dirsize=180568)
#         - gpcpgfh (file, size=123135
#         - gpcpgfh.zfp (file, size=57433
#     - zzclqz (dir, dirsize=217719)
#       - vcq.flg (file, size=217719
#
# 1517599

# %%
def find_smallest_to_delete(
    root_dir: Directory,
    total_size: int = 70000000,
    size_needed: int = 30000000,
) -> int:
    free_space = total_size - root_dir.size()
    space_to_clean = size_needed - free_space
    return root_dir.min_dir_over_threshold(space_to_clean).size()

# %%
test_input = parse_input("test-input.txt")
print(find_smallest_to_delete(test_input))
# Out:
# 24933642

# %%
test_input = parse_input("input.txt")
print(find_smallest_to_delete(test_input))
# Out:
# 2481982
